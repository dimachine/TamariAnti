# %% [markdown]
# # Counting (maximal) antichains in the Tamari lattice of order n
#
#
# This is a supporing file for OEIS on computation of (maximal) antichains in the Tamari lattice of order n.
#
# ## Outline
#
# ### 0. The basic code with the class for managing generation of formal concepts via NextClosure algorithm
#
# ### 1. Loading formal contexts for antichains and maximal antichains of Tamari lattice
#
# ### 2. Counting of maximal antichains for n in {0, 1, 2, 3, 4, 5}
#
# ### 3. Counting of  antichains for n in {0, 1, 2, 3, 4, 5}

# %%
class nnBitContext:
    def __init__(self, n=3, i=0, m=3):
            self.attr_names=[str(k+1) for k in range(n)]
            self.objects=[]
            self.obj_names=[str(k+1) for k in range(m)]
            #print(bin(i))
            for j in range(m):                
                self.objects.append(i & ((1<<n) - 1))
                #print(bin(i & ((1<<n) - 1)))
                i=i<<1
                #print(bin(i))
            self.nAttr=len(self.attr_names)
            self.nObj=len(self.objects)
            self.name="Context"

      
 
    def aClosure(self,aSet):
        #computing attribute closure
        B=(1<<self.nAttr)-1
        for g in self.objects:
            if aSet & g == aSet:
                B=B & g        
        return B
    
   
    
def cxtFromFile(filename):
    cxt=nnBitContext(0,0,0)
   
    f = open(filename, "r")
    print(f.readline())
    print(f.readline())
        
    cxt.nObj=int(f.readline())
    cxt.nAttr=int(f.readline())
    
    print(f.readline())
    
    for i in range(cxt.nObj):
        cxt.obj_names.append(f.readline())
    
    for i in range(cxt.nAttr):
        cxt.attr_names.append(f.readline())
    

    for l in range(cxt.nObj):
        o=f.readline().replace('.','0').replace('x','1')
        print(o)
        
        cxt.objects.append(int(o,2))
        #print(bin(i & ((1<<n) - 1)))
        
        #print(bin(i)
    cxt.name=filename[:-4]
    f.close()
    return cxt  


    
    
    
    
def BitNextClosure(A,bCxt):
    #print("Bit NextClosure")
    for m in range(bCxt.nAttr-1,-1,-1):
        #print("m=",m)
        if A & (1<<m):
            #print("A=",A)
            A= A & ~(1<<m)
            #print("A= A & ~(1<<m)",A)
        else:
            B=bCxt.aClosure(A |(1<<m))
            #print("A=",A,bin(A))
            #print("B=cl(AUm)",B)
            B_A=B & ~A
            #print("B-A",B_A,bin(B_A))
            if not B_A & ((1<<m)-1):
                #print("B_A", B_A, bin(B_A), "((1<<m)-1)", ((1<<m)-1), bin(((1<<m)-1)))  
                return B
    print("Branch terminated with -1")
    return -1  
    
    
    

def FirstClosure(bCxt):
    #print("First closure")
    if bCxt.objects==[]:
        return 2**bCxt.nAttr-1
    eCl=bCxt.objects[0]
    if eCl:
        for g in bCxt.objects[1:]:
            eCl= eCl & g 
  
    return eCl



def CountAllClosures(bCxt):
    
    #print("All closures")
    cnt=0
    prevcnt=0
    A=FirstClosure(bCxt)
    #print("First Closure",A,bin(A))
    while A!=-1:
        #print ("A=",A, "binary representation", bin(A))
        cnt+=1
        A=BitNextClosure(A,bCxt)
        if cnt%1000000==0: 
            if cnt!=prevcnt: 
                print(cnt)
                prevcnt=cnt
    return cnt

# %% [markdown]
# ### 1. Loading formal contexts for antichains and maximal antichains of a partition lattice

# %%
AC_cxts=[cxtFromFile("AC_Tamari"+str(i)+".cxt") for i in range(6)]
# Out:
# B
#
#
#
#
#
# 0
#
# B
#
#
#
#
#
# 0
#
# B
#
#
#
#
#
# 01
#
# 00
#
# B
#
#
#
#
#
# 01111
#
# 00111
#
# 01011
#
# 01001
#
# 00000
#
# B
#
#
#
#
#
# 01111111111111
#
# 00111111111111
#
# 01011111111111
#
# 01001111111111
#
# 00000111111111
#
# 01111011111111
#
# 00111001111111
#
# 01111010111111
#
# 01111010011111
#
# 00111000001111
#
# 01011010110111
#
# 01011010010011
#
# 01001010010001
#
# 00000000000000
#
# B
#
#
#
#
#
# 011111111111111111111111111111111111111111
#
# 001111111111111111111111111111111111111111
#
# 010111111111111111111111111111111111111111
#
# 010011111111111111111111111111111111111111
#
# 000001111111111111111111111111111111111111
#
# 011110111111111111111111111111111111111111
#
# 001110011111111111111111111111111111111111
#
# 011110101111111111111111111111111111111111
#
# 011110100111111111111111111111111111111111
#
# 001110000011111111111111111111111111111111
#
# 010110101101111111111111111111111111111111
#
# 010110100100111111111111111111111111111111
#
# 010010100100011111111111111111111111111111
#
# 000000000000001111111111111111111111111111
#
# 011111111111110111111111111111111111111111
#
# 001111111111110011111111111111111111111111
#
# 010111111111110101111111111111111111111111
#
# 010011111111110100111111111111111111111111
#
# 000001111111110000011111111111111111111111
#
# 011111111111110111101111111111111111111111
#
# 001111111111110011100111111111111111111111
#
# 011111111111110111101011111111111111111111
#
# 011111111111110111101001111111111111111111
#
# 001111111111110011100000111111111111111111
#
# 010111111111110101101011011111111111111111
#
# 010111111111110101101001001111111111111111
#
# 010011111111110100101001000111111111111111
#
# 000001111111110000000000000011111111111111
#
# 011110111111110111101111111101111111111111
#
# 001110011111110011100111111100111111111111
#
# 011110111111110111101011111101011111111111
#
# 011110111111110111101001111101001111111111
#
# 001110011111110011100000111100000111111111
#
# 011110101111110111101011111101011011111111
#
# 011110101111110111101001111101001001111111
#
# 011110100111110111101001111101001000111111
#
# 001110000011110011100000111100000000011111
#
# 010110101101110101101011011101011011101111
#
# 010110101101110101101001001101001001100111
#
# 010110100100110101101001001101001000100011
#
# 010010100100010100101001000101001000100001
#
# 000000000000000000000000000000000000000000

# %%
MA_cxts=[cxtFromFile("MA_Tamari"+str(i)+".cxt") for i in range(6)]
# Out:
# B
#
#
#
#
#
# 1
#
# B
#
#
#
#
#
# 1
#
# B
#
#
#
#
#
# 11
#
# 01
#
# B
#
#
#
#
#
# 11111
#
# 01111
#
# 01111
#
# 01011
#
# 00001
#
# B
#
#
#
#
#
# 11111111111111
#
# 01111111111111
#
# 01111111111111
#
# 01011111111111
#
# 00001111111111
#
# 01111111111111
#
# 00111011111111
#
# 01111011111111
#
# 01111010111111
#
# 00111000011111
#
# 01011010111111
#
# 01011010010111
#
# 01001010010011
#
# 00000000000001
#
# B
#
#
#
#
#
# 111111111111111111111111111111111111111111
#
# 011111111111111111111111111111111111111111
#
# 011111111111111111111111111111111111111111
#
# 010111111111111111111111111111111111111111
#
# 000011111111111111111111111111111111111111
#
# 011111111111111111111111111111111111111111
#
# 001110111111111111111111111111111111111111
#
# 011110111111111111111111111111111111111111
#
# 011110101111111111111111111111111111111111
#
# 001110000111111111111111111111111111111111
#
# 010110101111111111111111111111111111111111
#
# 010110100101111111111111111111111111111111
#
# 010010100100111111111111111111111111111111
#
# 000000000000011111111111111111111111111111
#
# 011111111111111111111111111111111111111111
#
# 001111111111110111111111111111111111111111
#
# 010111111111110111111111111111111111111111
#
# 010011111111110101111111111111111111111111
#
# 000001111111110000111111111111111111111111
#
# 011111111111110111111111111111111111111111
#
# 001111111111110011101111111111111111111111
#
# 011111111111110111101111111111111111111111
#
# 011111111111110111101011111111111111111111
#
# 001111111111110011100001111111111111111111
#
# 010111111111110101101011111111111111111111
#
# 010111111111110101101001011111111111111111
#
# 010011111111110100101001001111111111111111
#
# 000001111111110000000000000111111111111111
#
# 011110111111110111101111111111111111111111
#
# 001110011111110011100111111101111111111111
#
# 011110111111110111101011111101111111111111
#
# 011110111111110111101001111101011111111111
#
# 001110011111110011100000111100001111111111
#
# 011110101111110111101011111101011111111111
#
# 011110101111110111101001111101001011111111
#
# 011110100111110111101001111101001001111111
#
# 001110000011110011100000111100000000111111
#
# 010110101101110101101011011101011011111111
#
# 010110101101110101101001001101001001101111
#
# 010110100100110101101001001101001000100111
#
# 010010100100010100101001000101001000100011
#
# 000000000000000000000000000000000000000001

# %% [markdown]
# ### 2. Generation of maximal antichains for n in {0,1,2,3,4,5}

# %%
# %%time
MAs=[CountAllClosures(c) for c in  MA_cxts]
# Out:
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# CPU times: user 55.4 ms, sys: 1.88 ms, total: 57.2 ms
# Wall time: 57 ms

# %%
MAs
# Out:
# [1, 1, 2, 4, 26, 1979]

# %% [markdown]
# ### 3. Counting of  antichains for n in {0, 1, 2, 3, 4, 5}

# %%
# %%time
ACs=[CountAllClosures(c) for c in  AC_cxts]
# Out:
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# Branch terminated with -1
# CPU times: user 627 ms, sys: 5.12 ms, total: 633 ms
# Wall time: 633 ms

# %%
ACs
# Out:
# [2, 2, 3, 8, 83, 28984]
